# %%
# Import Library

import pandas as pd
import joblib

# %%
# Load model yang sudah disimpan
model = joblib.load('best_model.pkl')

# %%
#  Data Baru (1 mobil)
data_inference = pd.DataFrame({
    'Brand': ['Toyota'],
    'Year': [2019],
    'Gearbox': ['Automatic'],
    'Kilometers': [45000],
    'Fuel': ['Petrol'],
    'Type': ['Wagon'],
    'Seating Capacity': [7],
    'Variant': ['Build 2'],
    'Status': ['New In Stock'],
    'Model': ['Rukus'],
    'ID': ['11530348'],
    'CC': ['2362'],
    'Name': ['2015 Toyota Rukus Build 2 AZE3251R'],
    'Series': ['AZE151R'],
    'Color': ['Black']
})

# %%
# Lakukan prediksi
prediction = model.predict(data_inference)

prediction
# Out:
# array([47735.115])
